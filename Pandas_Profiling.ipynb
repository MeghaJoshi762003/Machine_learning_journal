# %%
from ydata_profiling import ProfileReport

# %%
import pandas as pd
df=pd.read_csv("./student_course_completion/Course_Completion_Prediction.csv")
prof=ProfileReport(df)

# %%
prof.to_file(output_file='profile.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# D:\machine learning\notebook\myenv\lib\site-packages\ydata_profiling\model\typeset_relations.py:117: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   return pd.to_datetime(series)
# D:\machine learning\notebook\myenv\lib\site-packages\ydata_profiling\model\typeset_relations.py:117: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   return pd.to_datetime(series)
# ...
